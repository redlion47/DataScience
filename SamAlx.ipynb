# %%
import pandas as pd
import numpy as np
import re

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import os, random, time, sys, requests, webbrowser

# %%
data = pd.read_csv('./mercy.csv')
print(data.shape)
data.head()
# Out:
# (457, 12)
#    S/N Person           Full Name First Name  Last Name  \
# 0    1  Mercy    Titilope Olajide   Titilope    Olajide
# 1    2  Mercy        Titus Mawano      Titus     Mawano
# 2    3  Mercy  Tlotliso Mafantiri   Tlotliso  Mafantiri
# 3    4  Mercy       Tobias Becker     Tobias     Becker
# 4    5  Mercy      Toby  Shapshak       Toby   Shapshak
#
#                   Email Address                                    Job Title  \
# 0  titilope.olajide@ng.kpmg.com  Associate Director/ Head, People and Change
# 1         titusmawano@gmail.com                                Founder & CEO
# 2    michaelmafantiri@gmail.com                            Software Engineer
# 3      tobias.becker@ae.abb.com          Head of Global Government Relations
# 4         toby@mavenmedia.co.za                             Founder & Owner
#
#           Organisation  Work Country          City  Region      Career Level
# 0     KPMG East Africa         Kenya       Nairobi  Africa               NaN
# 1            Ffene Ltd        Uganda       Kampala  Africa               NaN
# 2             Technify       Lesotho        Maseru  Africa  Students Parents
# 3  ABB Electrification   Switzerland        Zurich  Europe               NaN
# 4          Maven Media  South Africa  Johannesburg  Africa               NaN

# %%
def linkedin(test):
    test_cp = test.copy()
    # Instatiating Chrome
    driver = webdriver.Chrome('./chromedriver')
    # When Chrome opens maximize
    # driver.maximize_window()

    link_filter = ('hl=', 'q=', 'u=', '/pub/')

    # Open google
    driver.get('https://www.google.com')
    # Loop through
    for i in range(0, test_cp.shape[0]):
        # focus on search box
        search = driver.find_element_by_name("q")
        search.clear()
        # search name and organization
        search.send_keys('"{}"'.format(test_cp.iat[i, 2]) + ' ' + test_cp.iat[i, 5])
        # search
        search.submit()
        # match results with linkedin
        matched_elements = driver.find_elements_by_xpath('//a[contains(@href, "linkedin")]')
        # loop through all the matched elements
        for link in matched_elements:
            # make sure attribute is less the 100 characters
            if len(link.get_attribute('href')) < 85 and '/pub/' not in link.get_attribute('href'):
                
                # print(link.get_attribute('href'))
                test_cp.loc[(test['Full Name'] == test_cp.iat[i, 2]), 'Linkedin'] = link.get_attribute('href')
                
        time.sleep(8)

    return test_cp

# %%
dat_35 = linkedin(data.iloc[0:35])
dat_35.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        25 non-null object
# Email Address    35 non-null object
# Job Title        5 non-null object
# Organisation     0 non-null float64
# Careerl Level    5 non-null object
# Work Country     3 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         3 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.7+ KB

# %%
dat_70 = linkedin(data.iloc[35:70])
dat_70.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 35 to 69
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        27 non-null object
# Email Address    35 non-null object
# Job Title        2 non-null object
# Organisation     0 non-null float64
# Careerl Level    3 non-null object
# Work Country     3 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         13 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.7+ KB

# %%
dat_105 = linkedin(data.iloc[70:105])
dat_105.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 70 to 104
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        23 non-null object
# Email Address    35 non-null object
# Job Title        2 non-null object
# Organisation     0 non-null float64
# Careerl Level    3 non-null object
# Work Country     2 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         17 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.7+ KB

# %%
dat_140 = linkedin(data.iloc[105:140])
dat_140.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 105 to 139
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        23 non-null object
# Email Address    35 non-null object
# Job Title        1 non-null object
# Organisation     0 non-null float64
# Careerl Level    3 non-null object
# Work Country     4 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         12 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.7+ KB

# %%
dat_175 = linkedin(data.iloc[140:175])
dat_175.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 140 to 174
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        18 non-null object
# Email Address    35 non-null object
# Job Title        4 non-null object
# Organisation     0 non-null float64
# Careerl Level    4 non-null object
# Work Country     2 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         18 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 3.7+ KB

# %%
dat_ = linkedin(data.iloc[175:210])
dat_210.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 175 to 189
# Data columns (total 13 columns):
# S/N              15 non-null int64
# Person           15 non-null object
# Full Name        15 non-null object
# First Name       15 non-null object
# Last Name        14 non-null object
# Email Address    15 non-null object
# Job Title        2 non-null object
# Organisation     0 non-null float64
# Careerl Level    3 non-null object
# Work Country     1 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         4 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.7+ KB

# %%
data_lst = [dat_35, dat_70, dat_105, dat_140, dat_175, dat_210]
data_naf = pd.concat(data_lst)

# %%
data_naf.shape
# Out:
# (190, 13)

# %%
data_naf[data_naf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [S/N, Person, Full Name, First Name, Last Name, Email Address, Job Title, Organisation, Careerl Level, Work Country, City, Region, Linkedin]
# Index: []

# %%
data_naf.to_csv('mercy_linkedin.csv')

# %%
key = 'AIzaSyD9gUTldXJ6uyO5W1xvcZIDOWxUqALbxA0'
engine_id = '009104355705785336217:fbibydpv9z0'

# %%
data_100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
# S/N              100 non-null int64
# Person           100 non-null object
# Full Name        100 non-null object
# First Name       100 non-null object
# Last Name        91 non-null object
# Email Address    100 non-null object
# Job Title        10 non-null object
# Organisation     4 non-null object
# Careerl Level    20 non-null object
# Work Country     18 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         41 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.3+ KB

# %%
dat_135 = linkedin(data.iloc[100:135])
dat_135.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 100 to 134
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        32 non-null object
# Email Address    35 non-null object
# Job Title        3 non-null object
# Organisation     0 non-null object
# Careerl Level    9 non-null object
# Work Country     10 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         10 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_170 = linkedin(data.iloc[135:170])
dat_170.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 135 to 169
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        32 non-null object
# Email Address    35 non-null object
# Job Title        3 non-null object
# Organisation     1 non-null object
# Careerl Level    9 non-null object
# Work Country     9 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         16 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_205 = linkedin(data.iloc[170:205])
dat_205.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 170 to 204
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        32 non-null object
# Email Address    35 non-null object
# Job Title        6 non-null object
# Organisation     0 non-null object
# Careerl Level    6 non-null object
# Work Country     7 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         14 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_lst2 = [dat_135, dat_170, dat_205]
dat_200 = pd.concat(dat_lst2)
dat_200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 100 to 204
# Data columns (total 13 columns):
# S/N              105 non-null int64
# Person           105 non-null object
# Full Name        105 non-null object
# First Name       105 non-null object
# Last Name        96 non-null object
# Email Address    105 non-null object
# Job Title        12 non-null object
# Organisation     1 non-null object
# Careerl Level    24 non-null object
# Work Country     26 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         40 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.8+ KB

# %%
dat_240 = linkedin(data.iloc[205:240])
dat_240.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 205 to 239
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        24 non-null object
# Email Address    35 non-null object
# Job Title        4 non-null object
# Organisation     2 non-null object
# Careerl Level    3 non-null object
# Work Country     3 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         16 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_240[pd.notnull(dat_240['Linkedin'])]
# Out:
#       S/N Person          Full Name First Name Last Name  \
# 212  4405    Sam             Raman       Raman       NaN
# 213  4406    Sam             Raman       Raman       NaN
# 216  4409    Sam          Ramdanee    Ramdanee       NaN
# 217  4410    Sam              Ramy        Ramy       NaN
# 218  4411    Sam        Rana Gamali       Rana    Gamali
# 219  4412    Sam      Randolph Fabi   Randolph      Fabi
# 222  4415    Sam        Randy Buday      Randy     Buday
# 223  4416    Sam             Rania       Rania       NaN
# 224  4417    Sam             Rania       Rania       NaN
# 226  4419    Sam           Ranjeev     Ranjeev       NaN
# 227  4420    Sam               Rao         Rao       NaN
# 229  4422    Sam      Raoul Gufflet      Raoul   Gufflet
# 230  4423    Sam      Raphael Benza    Raphael     Benza
# 235  4428    Sam      Rasha Makkawi      Rasha   Makkawi
# 236  4429    Sam  Rashidat Boladale   Rashidat  Boladale
# 238  4431    Sam     Rathipe Nthite    Rathipe    Nthite
#
#                        Email Address               Job Title Organisation  \
# 212               raman@nakumatt.net                     NaN          NaN
# 213              ramanquah@gmail.com                     NaN          NaN
# 216          s.ramdanee@maradiva.com                     NaN          NaN
# 217              ramy@madeomedia.com                     NaN          NaN
# 218    rana.gamali@cocacolaegypt.com                     NaN          NaN
# 219              randyfabi@gmail.com                     NaN          NaN
# 222              randy.buday@dhl.com                     NaN          NaN
# 223              rania2215@yahoo.com                     NaN          NaN
# 224                 rania@gebraa.com                     NaN          NaN
# 226        ranjeev@argus-trading.com                     NaN          NaN
# 227              rao@eskaypharma.com                     NaN          NaN
# 229             raoul.gufflet@mcb.mu  Deputy Chief Executive          NaN
# 230          raphael.benza@gmail.com                     NaN          NaN
# 235         rasha.makkawi@abraaj.com                     NaN          NaN
# 236  rashidat.boladale@ng.nestle.com                     NaN          NaN
# 238   rathipe.nthite@treasury.gov.za                     NaN          NaN
#
#     Careerl Level Work Country  City Region  \
# 212           NaN          NaN   NaN    NaN
# 213           NaN          NaN   NaN    NaN
# 216           NaN          NaN   NaN    NaN
# 217           NaN          NaN   NaN    NaN
# 218           NaN          NaN   NaN    NaN
# 219           NaN          NaN   NaN    NaN
# 222           NaN          NaN   NaN    NaN
# 223           NaN          NaN   NaN    NaN
# 224           NaN          NaN   NaN    NaN
# 226           NaN          NaN   NaN    NaN
# 227           NaN          NaN   NaN    NaN
# 229           NaN    Mauritius   NaN    NaN
# 230           NaN          NaN   NaN    NaN
# 235           NaN          NaN   NaN    NaN
# 236           NaN          NaN   NaN    NaN
# 238           NaN          NaN   NaN    NaN
#
#                                               Linkedin
# 212  https://ke.linkedin.com/in/raman-subramanian-b...
# 213  https://ke.linkedin.com/in/raman-subramanian-b...
# 216  https://mu.linkedin.com/in/sanjiv-ramdanee-749...
# 217               https://www.linkedin.com/in/ramynagy
# 218    https://eg.linkedin.com/in/rana-gamali-21553414
# 219      https://uk.linkedin.com/in/randy-fabi-3500234
# 222    https://ng.linkedin.com/in/randy-buday-361a8516
# 223  https://eg.linkedin.com/in/rania-salah-seddik-...
# 224  https://eg.linkedin.com/in/rania-salah-seddik-...
# 226  https://ke.linkedin.com/in/aditi-kimatrai-0039...
# 227  https://ke.linkedin.com/in/pemmaraju-balaram-r...
# 229          https://www.linkedin.com/company/mcbgroup
# 230       https://za.linkedin.com/directory/people-r-9
# 235  https://eg.linkedin.com/in/rasha-makkawi-64128a16
# 236  https://ng.linkedin.com/in/oluwatunmise-adeko-...
# 238  https://za.linkedin.com/in/ghalib-tombey-58459...

# %%
dat_275 = linkedin(data.iloc[240:275])
dat_275.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 240 to 274
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        30 non-null object
# Email Address    35 non-null object
# Job Title        8 non-null object
# Organisation     0 non-null object
# Careerl Level    4 non-null object
# Work Country     8 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         15 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_320 = linkedin(data.iloc[275:310])
dat_320.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 275 to 309
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        26 non-null object
# Email Address    35 non-null object
# Job Title        3 non-null object
# Organisation     0 non-null object
# Careerl Level    2 non-null object
# Work Country     4 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         14 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dt_ls3 = [dat_240, dat_275, dat_320]
dat_300 = pd.concat(dt_ls3)
dat_300.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 205 to 309
# Data columns (total 13 columns):
# S/N              105 non-null int64
# Person           105 non-null object
# Full Name        105 non-null object
# First Name       105 non-null object
# Last Name        80 non-null object
# Email Address    105 non-null object
# Job Title        15 non-null object
# Organisation     2 non-null object
# Careerl Level    9 non-null object
# Work Country     15 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         45 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.8+ KB

# %%
dat_345 = linkedin(data.iloc[310:345])
dat_345.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 310 to 344
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        29 non-null object
# Email Address    35 non-null object
# Job Title        4 non-null object
# Organisation     0 non-null object
# Careerl Level    3 non-null object
# Work Country     3 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         17 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_380 = linkedin(data.iloc[345:380])
dat_380.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 345 to 379
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        28 non-null object
# Email Address    35 non-null object
# Job Title        4 non-null object
# Organisation     0 non-null object
# Careerl Level    1 non-null object
# Work Country     4 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         19 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_415 = linkedin(data.iloc[380:415])
dat_415.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 380 to 414
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        29 non-null object
# Email Address    35 non-null object
# Job Title        3 non-null object
# Organisation     2 non-null object
# Careerl Level    11 non-null object
# Work Country     12 non-null object
# City             0 non-null float64
# Region           2 non-null object
# Linkedin         16 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dt_lst4 = [dat_345, dat_380, dat_415]
dat_400 = pd.concat(dt_lst4)
dat_400.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 310 to 414
# Data columns (total 13 columns):
# S/N              105 non-null int64
# Person           105 non-null object
# Full Name        105 non-null object
# First Name       105 non-null object
# Last Name        86 non-null object
# Email Address    105 non-null object
# Job Title        11 non-null object
# Organisation     2 non-null object
# Careerl Level    15 non-null object
# Work Country     19 non-null object
# City             0 non-null float64
# Region           4 non-null object
# Linkedin         52 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.8+ KB

# %%
dat_450 = linkedin(data.iloc[415:450])
dat_450.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 415 to 449
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        30 non-null object
# Email Address    35 non-null object
# Job Title        2 non-null object
# Organisation     0 non-null object
# Careerl Level    10 non-null object
# Work Country     6 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         16 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_485 = linkedin(data.iloc[450:485])
dat_485.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 450 to 484
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        29 non-null object
# Email Address    35 non-null object
# Job Title        6 non-null object
# Organisation     0 non-null object
# Careerl Level    10 non-null object
# Work Country     7 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         14 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
len(dat_485)
# Out:
# 35

# %%
dat_520 = linkedin(data.iloc[485:520])
dat_485.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 450 to 484
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        29 non-null object
# Email Address    35 non-null object
# Job Title        6 non-null object
# Organisation     0 non-null object
# Careerl Level    10 non-null object
# Work Country     7 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         14 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_520.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 485 to 519
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        29 non-null object
# Email Address    35 non-null object
# Job Title        4 non-null object
# Organisation     1 non-null object
# Careerl Level    1 non-null object
# Work Country     0 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         12 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dt_lst5 = [dat_450, dat_485, dat_520]
dat_500 = pd.concat(dt_lst5)
dat_500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 415 to 519
# Data columns (total 13 columns):
# S/N              105 non-null int64
# Person           105 non-null object
# Full Name        105 non-null object
# First Name       105 non-null object
# Last Name        88 non-null object
# Email Address    105 non-null object
# Job Title        12 non-null object
# Organisation     1 non-null object
# Careerl Level    21 non-null object
# Work Country     13 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         42 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.8+ KB

# %%
dat_555 = linkedin(data.iloc[520:555])
dat_555.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 520 to 554
# Data columns (total 13 columns):
# S/N              35 non-null int64
# Person           35 non-null object
# Full Name        35 non-null object
# First Name       35 non-null object
# Last Name        33 non-null object
# Email Address    35 non-null object
# Job Title        6 non-null object
# Organisation     1 non-null object
# Careerl Level    7 non-null object
# Work Country     3 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         17 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.7+ KB

# %%
dat_580 = linkedin(data.iloc[555:-1])
dat_580.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 555 to 575
# Data columns (total 13 columns):
# S/N              21 non-null int64
# Person           21 non-null object
# Full Name        21 non-null object
# First Name       21 non-null object
# Last Name        20 non-null object
# Email Address    21 non-null object
# Job Title        4 non-null object
# Organisation     0 non-null object
# Careerl Level    2 non-null object
# Work Country     3 non-null object
# City             0 non-null float64
# Region           0 non-null object
# Linkedin         6 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 2.3+ KB

# %%
dt_lst_fin = [dat_555, dat_580]
df_fin = pd.concat(dt_lst_fin)
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 520 to 575
# Data columns (total 13 columns):
# S/N              56 non-null int64
# Person           56 non-null object
# Full Name        56 non-null object
# First Name       56 non-null object
# Last Name        53 non-null object
# Email Address    56 non-null object
# Job Title        10 non-null object
# Organisation     1 non-null object
# Careerl Level    9 non-null object
# Work Country     6 non-null object
# City             0 non-null float64
# Region           1 non-null object
# Linkedin         23 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.8+ KB

# %%
fin_lst = [data_100, dat_200, dat_300, dat_400, dat_500, df_fin]

# %%
fin_df = pd.concat(fin_lst)
fin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 13 columns):
# S/N              576 non-null int64
# Person           576 non-null object
# Full Name        576 non-null object
# First Name       576 non-null object
# Last Name        494 non-null object
# Email Address    576 non-null object
# Job Title        70 non-null object
# Organisation     11 non-null object
# Careerl Level    98 non-null object
# Work Country     97 non-null object
# City             0 non-null float64
# Region           8 non-null object
# Linkedin         243 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 58.6+ KB

# %%
for i in fin_lst:
    print(i.shape)
# Out:
# (100, 13)
# (105, 13)
# (105, 13)
# (105, 13)
# (105, 13)
# (56, 13)

# %%
fin_df.to_csv('Linkedin.csv')

# %%
upd_dat = fin_df.copy()

upd_dat.nunique()
# Out:
# S/N              576
# Person             1
# Full Name        555
# First Name       336
# Last Name        478
# Email Address    576
# Job Title         47
# Organisation      11
# Careerl Level      6
# Work Country      22
# City               0
# Region             2
# Linkedin         225
# dtype: int64

# %%
test = upd_dat.loc[: ,upd_dat.columns != 'Linkedin'] 
test.shape
# Out:
# (576, 12)

# %%
org_dat = data.copy()

# %%
missing = pd.concat([org_dat, test]).drop_duplicates(keep=False)
missing
# Out:
#       S/N Person      Full Name First Name Last Name       Email Address  \
# 576  4769    Sam  Santg Dantata      Santg   Dantata  sdantata@gmail.com
#
#     Job Title Organisation Careerl Level Work Country  City Region
# 576       NaN          NaN           NaN          NaN   NaN    NaN

# %%
miss = linkedin(missing)

# %%
upd_dat = pd.concat([upd_dat, miss])
upd_dat.shape
# Out:
# /home/jedi/.pyenv/versions/anaconda3-5.3.0/envs/PyR/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (577, 13)

# %%
upd_dat.to_csv('Linkedin.csv')

# %%
upd_dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 576
# Data columns (total 13 columns):
# Careerl Level    98 non-null object
# City             0 non-null float64
# Email Address    577 non-null object
# First Name       577 non-null object
# Full Name        577 non-null object
# Job Title        70 non-null object
# Last Name        495 non-null object
# Linkedin         243 non-null object
# Organisation     11 non-null object
# Person           577 non-null object
# Region           8 non-null object
# S/N              577 non-null int64
# Work Country     97 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 63.1+ KB

# %%
upd_dat1 = pd.concat([fin_df, miss])
upd_dat1.head()
# Out:
# /home/jedi/.pyenv/versions/anaconda3-5.3.0/envs/PyR/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#   Careerl Level  City                    Email Address First Name  \
# 0           NaN   NaN       pwafula@ke.nationmedia.com       Paul
# 1           NaN   NaN  paul.west@newforestscompany.com       Paul
# 2           NaN   NaN             paul.yange@grioo.com       Paul
# 3           NaN   NaN     paula@phillipsconsulting.net      Paula
# 4           NaN   NaN               pauline@m-kopa.com    Pauline
#
#      Full Name Job Title Last Name  \
# 0  Paul Wafula       NaN    Wafula
# 1    Paul West       NaN      West
# 2   Paul Yange       NaN     Yange
# 3       Paula        NaN       NaN
# 4     Pauline        NaN       NaN
#
#                                             Linkedin Organisation Person  \
# 0                                                NaN          NaN    Sam
# 1                                                NaN          NaN    Sam
# 2                                                NaN          NaN    Sam
# 3  https://www.linkedin.com/company/phillips-cons...          NaN    Sam
# 4   https://ke.linkedin.com/in/pauline-komu-54b90247          NaN    Sam
#
#   Region   S/N Work Country
# 0    NaN  4193          NaN
# 1    NaN  4194          NaN
# 2    NaN  4195          NaN
# 3    NaN  4196          NaN
# 4    NaN  4197          NaN

# %%
fin_df.shape
# Out:
# (576, 13)

# %%
col_ord = fin_df.columns.tolist()

# %%
miss
# Out:
#       S/N Person      Full Name First Name Last Name       Email Address  \
# 576  4769    Sam  Santg Dantata      Santg   Dantata  sdantata@gmail.com
#
#     Job Title Organisation Careerl Level Work Country  City Region
# 576       NaN          NaN           NaN          NaN   NaN    NaN

# %%
# miss = miss[col_]
upd_dat1.head()
# Out:
#   Careerl Level  City                    Email Address First Name  \
# 0           NaN   NaN       pwafula@ke.nationmedia.com       Paul
# 1           NaN   NaN  paul.west@newforestscompany.com       Paul
# 2           NaN   NaN             paul.yange@grioo.com       Paul
# 3           NaN   NaN     paula@phillipsconsulting.net      Paula
# 4           NaN   NaN               pauline@m-kopa.com    Pauline
#
#      Full Name Job Title Last Name  \
# 0  Paul Wafula       NaN    Wafula
# 1    Paul West       NaN      West
# 2   Paul Yange       NaN     Yange
# 3       Paula        NaN       NaN
# 4     Pauline        NaN       NaN
#
#                                             Linkedin Organisation Person  \
# 0                                                NaN          NaN    Sam
# 1                                                NaN          NaN    Sam
# 2                                                NaN          NaN    Sam
# 3  https://www.linkedin.com/company/phillips-cons...          NaN    Sam
# 4   https://ke.linkedin.com/in/pauline-komu-54b90247          NaN    Sam
#
#   Region   S/N Work Country
# 0    NaN  4193          NaN
# 1    NaN  4194          NaN
# 2    NaN  4195          NaN
# 3    NaN  4196          NaN
# 4    NaN  4197          NaN

# %%
res = upd_dat1[col_ord]
res.head()
# Out:
#     S/N Person    Full Name First Name Last Name  \
# 0  4193    Sam  Paul Wafula       Paul    Wafula
# 1  4194    Sam    Paul West       Paul      West
# 2  4195    Sam   Paul Yange       Paul     Yange
# 3  4196    Sam       Paula       Paula       NaN
# 4  4197    Sam     Pauline     Pauline       NaN
#
#                      Email Address Job Title Organisation Careerl Level  \
# 0       pwafula@ke.nationmedia.com       NaN          NaN           NaN
# 1  paul.west@newforestscompany.com       NaN          NaN           NaN
# 2             paul.yange@grioo.com       NaN          NaN           NaN
# 3     paula@phillipsconsulting.net       NaN          NaN           NaN
# 4               pauline@m-kopa.com       NaN          NaN           NaN
#
#   Work Country  City Region                                           Linkedin
# 0          NaN   NaN    NaN                                                NaN
# 1          NaN   NaN    NaN                                                NaN
# 2          NaN   NaN    NaN                                                NaN
# 3          NaN   NaN    NaN  https://www.linkedin.com/company/phillips-cons...
# 4          NaN   NaN    NaN   https://ke.linkedin.com/in/pauline-komu-54b90247

# %%
res.to_csv('Linkedin.csv')

# %%
linked_df = pd.read_csv('Linkedin.csv')
print(linked_df.shape)
linked_df.head()
# Out:
# (577, 14)
#    Unnamed: 0   S/N Person    Full Name First Name Last Name  \
# 0           0  4193    Sam  Paul Wafula       Paul    Wafula
# 1           1  4194    Sam    Paul West       Paul      West
# 2           2  4195    Sam   Paul Yange       Paul     Yange
# 3           3  4196    Sam       Paula       Paula       NaN
# 4           4  4197    Sam     Pauline     Pauline       NaN
#
#                      Email Address Job Title Organisation Careerl Level  \
# 0       pwafula@ke.nationmedia.com       NaN          NaN           NaN
# 1  paul.west@newforestscompany.com       NaN          NaN           NaN
# 2             paul.yange@grioo.com       NaN          NaN           NaN
# 3     paula@phillipsconsulting.net       NaN          NaN           NaN
# 4               pauline@m-kopa.com       NaN          NaN           NaN
#
#   Work Country  City Region                                           Linkedin
# 0          NaN   NaN    NaN                                                NaN
# 1          NaN   NaN    NaN                                                NaN
# 2          NaN   NaN    NaN                                                NaN
# 3          NaN   NaN    NaN  https://www.linkedin.com/company/phillips-cons...
# 4          NaN   NaN    NaN   https://ke.linkedin.com/in/pauline-komu-54b90247

# %%
linked_df.columns
# Out:
# Index(['Unnamed: 0', 'S/N', 'Person', 'Full Name', 'First Name', 'Last Name',
#        'Email Address', 'Job Title', 'Organisation', 'Careerl Level',
#        'Work Country', 'City', 'Region', 'Linkedin'],
#       dtype='object')

# %%
linked_df.drop('Unnamed: 0', inplace=True ,axis=1)

# %%
linked_df.head()
# Out:
#     S/N Person    Full Name First Name Last Name  \
# 0  4193    Sam  Paul Wafula       Paul    Wafula
# 1  4194    Sam    Paul West       Paul      West
# 2  4195    Sam   Paul Yange       Paul     Yange
# 3  4196    Sam       Paula       Paula       NaN
# 4  4197    Sam     Pauline     Pauline       NaN
#
#                      Email Address Job Title Organisation Careerl Level  \
# 0       pwafula@ke.nationmedia.com       NaN          NaN           NaN
# 1  paul.west@newforestscompany.com       NaN          NaN           NaN
# 2             paul.yange@grioo.com       NaN          NaN           NaN
# 3     paula@phillipsconsulting.net       NaN          NaN           NaN
# 4               pauline@m-kopa.com       NaN          NaN           NaN
#
#   Work Country  City Region                                           Linkedin
# 0          NaN   NaN    NaN                                                NaN
# 1          NaN   NaN    NaN                                                NaN
# 2          NaN   NaN    NaN                                                NaN
# 3          NaN   NaN    NaN  https://www.linkedin.com/company/phillips-cons...
# 4          NaN   NaN    NaN   https://ke.linkedin.com/in/pauline-komu-54b90247

# %%
linked = linked_df[pd.notnull(linked_df['Linkedin'])]

# %%
577 - linked.shape[0]
# Out:
# 334

# %%
linked.to_csv('Linked.csv')

# %%
corr_links = linked[linked['Linkedin'].str.contains('/in/')==True]
corr_links.shape
# Out:
# (200, 13)

# %%
corr_links.head()
# Out:
#      S/N Person        Full Name First Name Last Name  \
# 4   4197    Sam         Pauline     Pauline       NaN
# 5   4198    Sam         Pauline     Pauline       NaN
# 6   4199    Sam         Pauline     Pauline       NaN
# 8   4201    Sam  Pauline Wachira    Pauline   Wachira
# 10  4203    Sam     Paulo Thomas      Paulo    Thomas
#
#                       Email Address Job Title                Organisation  \
# 4                pauline@m-kopa.com       NaN                         NaN
# 5     pauline.let@contourglobal.com       NaN                         NaN
# 6              pauline@etrade.co.ke       NaN                         NaN
# 8               pmuhonja1@gmail.com       NaN                         NaN
# 10  paulo.tomas@millenniumangola.ao       NaN  Banco Millennium Angola SA
#
#    Careerl Level Work Country  City Region  \
# 4            NaN          NaN   NaN    NaN
# 5            NaN          NaN   NaN    NaN
# 6            NaN          NaN   NaN    NaN
# 8      AL Family        Kenya   NaN    NaN
# 10           NaN          NaN   NaN    NaN
#
#                                              Linkedin
# 4    https://ke.linkedin.com/in/pauline-komu-54b90247
# 5    https://ke.linkedin.com/in/pauline-komu-54b90247
# 6    https://ke.linkedin.com/in/pauline-komu-54b90247
# 8   https://ke.linkedin.com/in/pauline-wachira-959...
# 10  https://www.linkedin.com/in/paulo-tom%C3%A1s-8...

# %%
corr_links.to_csv('corr_link.csv')

# %%
linked.shape
# Out:
# (243, 13)

# %%
linked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 3 to 570
# Data columns (total 13 columns):
# S/N              243 non-null int64
# Person           243 non-null object
# Full Name        243 non-null object
# First Name       243 non-null object
# Last Name        193 non-null object
# Email Address    243 non-null object
# Job Title        24 non-null object
# Organisation     9 non-null object
# Careerl Level    32 non-null object
# Work Country     35 non-null object
# City             0 non-null float64
# Region           5 non-null object
# Linkedin         243 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 26.6+ KB

# %%
data.shape
# Out:
# (577, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 12 columns):
# S/N              577 non-null int64
# Person           577 non-null object
# Full Name        577 non-null object
# First Name       577 non-null object
# Last Name        495 non-null object
# Email Address    577 non-null object
# Job Title        70 non-null object
# Organisation     11 non-null object
# Careerl Level    98 non-null object
# Work Country     97 non-null object
# City             0 non-null float64
# Region           8 non-null object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 54.2+ KB

# %%
profiles = pd.read_csv('./result.csv')
profiles.head()
# Out:
#                                      linkedinProfile  \
# 0        https://www.linkedin.com/in/hollonstevens/#
# 1            https://www.linkedin.com/in/tchiderov/#
# 2  https://www.linkedin.com/in/ebere-maduka-a342b...
# 3               https://www.linkedin.com/in/vreeti/#
# 4                                                NaN
#
#                                          description  \
# 0  Impact-driven and customer-focused senior lead...
# 1  Experienced professional with strong internati...
# 2  To work with existing staff and facilities con...
# 3  After studying for an MPhil in Economics from ...
# 4                                                NaN
#
#                                               imgUrl firstName  lastName  \
# 0  https://media.licdn.com/dms/image/C4D03AQFK_Tt...    Hollon   Stevens
# 1  https://media.licdn.com/dms/image/C4E03AQGLTZU...  Tzviatko  Chiderov
# 2  ......     EBERE    MADUKA
# 3  https://media.licdn.com/dms/image/C5103AQFQ1-8...    Vreeti    Reetoo
# 4                                                NaN       NaN       NaN
#
#             fullName connectionDegree  \
# 0     Hollon Stevens
# 1  Tzviatko Chiderov
# 2       EBERE MADUKA
# 3      Vreeti Reetoo              3rd
# 4                NaN              NaN
#
#                                       vmid  \
# 0  ACoAAAAqzzwB2uaFfi7_fJW-TfG0H-j6-phbtDk
# 1  ACoAAACdWr0BRnW4Qffxo9e5dENzApqdSHpltd0
# 2  ACoAAByFVYgBe2JQyIkhoWKmwUKQrobGqstH2z0
# 3  ACoAAAoFMOMBituKjqwgQiFvAzAKH-O7kzuWcn4
# 4                                      NaN
#
#                            linkedinSalesNavigatorUrl                 company  \
# 0  https://www.linkedin.com/sales/people/ACoAAAAq...  Independent Consultant
# 1  https://www.linkedin.com/sales/people/ACoAAACd...                Occasion
# 2  https://www.linkedin.com/sales/people/ACoAAByF...      Old Mutual Nigeria
# 3  https://www.linkedin.com/sales/people/ACoAAAoF...           ALU Education
# 4                                                NaN                     NaN
#
#    ...       location2                                  schoolDescription  \
# 0  ...             NaN                                                NaN
# 1  ...          Remote  Multidisciplinary degree in sustainable develo...
# 2  ...  Kaduna NIgeria                                          class Rep
# 3  ...             NaN                                                NaN
# 4  ...             NaN                                                NaN
#
#                schoolDegreeSpec schoolDateRange  \
# 0                           NaN             NaN
# 1  African Studies, Agriculture     2014 – 2015
# 2  Geography and Remote Sensing     2008 – 2012
# 3                     Economics     2012 – 2013
# 4                           NaN             NaN
#
#                                   schoolDescription2 schoolDateRange2  \
# 0                                                NaN              NaN
# 1  Co-Founded the International Club and Bulgaria...      2003 – 2007
# 2                                                NaN              NaN
# 3                                                NaN      2009 – 2012
# 4                                                NaN              NaN
#
#   mutualConnectionsUrl mutualConnectionsCount twitter birthday
# 0                  NaN                    NaN     NaN      NaN
# 1                  NaN                    NaN     NaN      NaN
# 2                  NaN                    NaN     NaN      NaN
# 3                  NaN                    NaN     NaN      NaN
# 4                  NaN                    NaN     NaN      NaN
#
# [5 rows x 53 columns]

# %%
profiles.columns.tolist()
# Out:
# ['linkedinProfile',
#  'description',
#  'imgUrl',
#  'firstName',
#  'lastName',
#  'fullName',
#  'connectionDegree',
#  'vmid',
#  'linkedinSalesNavigatorUrl',
#  'company',
#  'companyUrl',
#  'jobTitle',
#  'jobDescription',
#  'jobDateRange',
#  'company2',
#  'companyUrl2',
#  'jobTitle2',
#  'jobDateRange2',
#  'school',
#  'schoolUrl',
#  'schoolDegree',
#  'school2',
#  'schoolUrl2',
#  'schoolDegree2',
#  'schoolDegreeSpec2',
#  'allSkills',
#  'skill1',
#  'endorsement1',
#  'skill2',
#  'endorsement2',
#  'skill3',
#  'endorsement3',
#  'skill4',
#  'endorsement4',
#  'skill5',
#  'endorsement5',
#  'skill6',
#  'endorsement6',
#  'baseUrl',
#  'profileId',
#  'timestamp',
#  'location',
#  'jobDescription2',
#  'location2',
#  'schoolDescription',
#  'schoolDegreeSpec',
#  'schoolDateRange',
#  'schoolDescription2',
#  'schoolDateRange2',
#  'mutualConnectionsUrl',
#  'mutualConnectionsCount',
#  'twitter',
#  'birthday']

# %%
profiles1 = pd.read_csv('./filtered_linked_1.csv')
print(profiles1.shape)
profiles1.head()
# Out:
# (88, 7)
#                   fullName                                 company  \
# 0    Reshoketswe Mapokgole                         Equal Education
# 1         Cornelius Kitevu                    Civil Services, Inc.
# 2             Richard Bell  Technology & Renewable Energy Industry
# 3             Richard Bell  Technology & Renewable Energy Industry
# 4  Miguel Ferrer Giovanola                     Lombard Odier Group
#
#                       jobTitle               company2              jobTitle2  \
# 0  Senior Curriculum Developer  Mzansi Poetry Academy            Facilitator
# 1     Non Commissioned Officer                    NaN                    NaN
# 2           Investor & Advisor           KOOBA Africa                Founder
# 3           Investor & Advisor           KOOBA Africa                Founder
# 4        Senior Private Banker                   HSBC  Senior Private Banker
#
#                    location  Unnamed: 6
# 0               Khayelitsha         NaN
# 1                       NaN         NaN
# 2                   Nairobi         NaN
# 3                   Nairobi         NaN
# 4  Région de Genève, Suisse         NaN

# %%
profiles2 = pd.read_csv('./linked_1.csv')
print(profiles2.shape)
profiles2.head()
# Out:
# (88, 53)
#                                      linkedinProfile  \
# 0  https://www.linkedin.com/in/reshoketswe-mapokg...
# 1  https://www.linkedin.com/in/cornelius-kitevu-0...
# 2  https://www.linkedin.com/in/richard-bell-4b816...
# 3  https://www.linkedin.com/in/richard-bell-4b816...
# 4  https://www.linkedin.com/in/miguel-ferrer-giov...
#
#                                               imgUrl    firstName  \
# 0  ......  Reshoketswe
# 1  ......    Cornelius
# 2  https://media.licdn.com/dms/image/C4E03AQFa7Lb...      Richard
# 3  https://media.licdn.com/dms/image/C4E03AQFa7Lb...      Richard
# 4  https://media.licdn.com/dms/image/C5603AQEnjMp...       Miguel
#
#            lastName                 fullName connectionDegree  \
# 0         Mapokgole    Reshoketswe Mapokgole
# 1            Kitevu         Cornelius Kitevu
# 2              Bell             Richard Bell              3rd
# 3              Bell             Richard Bell              3rd
# 4  Ferrer Giovanola  Miguel Ferrer Giovanola
#
#                                       vmid  \
# 0  ACoAAAsuAO0B3H6U55EpdIGHXer-EryDN6Di6os
# 1  ACoAACWN-rQBLkicNIOJNDYyLKNcKk29T31izSY
# 2  ACoAAABhGEwBLzOiCvdEMGiIVeaOEJEvDUliNrs
# 3  ACoAAABhGEwBLzOiCvdEMGiIVeaOEJEvDUliNrs
# 4  ACoAACcrZqgBRzmlEjBZek--RafXulVr6maTzb8
#
#                            linkedinSalesNavigatorUrl  \
# 0  https://www.linkedin.com/sales/people/ACoAAAsu...
# 1  https://www.linkedin.com/sales/people/ACoAACWN...
# 2  https://www.linkedin.com/sales/people/ACoAAABh...
# 3  https://www.linkedin.com/sales/people/ACoAAABh...
# 4  https://www.linkedin.com/sales/people/ACoAACcr...
#
#                                   company  \
# 0                         Equal Education
# 1                    Civil Services, Inc.
# 2  Technology & Renewable Energy Industry
# 3  Technology & Renewable Energy Industry
# 4                     Lombard Odier Group
#
#                                           companyUrl  ...  \
# 0  https://www.linkedin.com/company/equal-educati...  ...
# 1  https://www.linkedin.com/company/civil-service...  ...
# 2  https://www.linkedin.com/search/results/index/...  ...
# 3  https://www.linkedin.com/search/results/index/...  ...
# 4    https://www.linkedin.com/company/lombard-odier/  ...
#
#                         profileId                 timestamp  \
# 0  reshoketswe-mapokgole-17999452  2019-10-23T12:47:10.239Z
# 1      cornelius-kitevu-09800b157  2019-10-23T12:47:24.328Z
# 2            richard-bell-4b816a2  2019-10-23T12:47:39.891Z
# 3            richard-bell-4b816a2  2019-10-23T12:47:55.509Z
# 4         miguel-ferrer-giovanola  2019-10-23T12:48:09.777Z
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2  Experienced Investor with a demonstrated histo...
# 3  Experienced Investor with a demonstrated histo...
# 4                                                NaN
#
#                                       jobDescription subscribers  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  Investor, Advisor & Manager in Technology Indu...         NaN
# 3  Investor, Advisor & Manager in Technology Indu...         NaN
# 4                                                NaN         NaN
#
#   schoolDescription2 twitter schoolDescription birthday facebookUrl
# 0                NaN     NaN               NaN      NaN         NaN
# 1                NaN     NaN               NaN      NaN         NaN
# 2                NaN     NaN               NaN      NaN         NaN
# 3                NaN     NaN               NaN      NaN         NaN
# 4                NaN     NaN               NaN      NaN         NaN
#
# [5 rows x 53 columns]

# %%
profiles1['Linkedin'] = profiles2['linkedinProfile']

# %%
profiles1
# Out:
#                    fullName                                 company  \
# 0     Reshoketswe Mapokgole                         Equal Education
# 1          Cornelius Kitevu                    Civil Services, Inc.
# 2              Richard Bell  Technology & Renewable Energy Industry
# 3              Richard Bell  Technology & Renewable Energy Industry
# 4   Miguel Ferrer Giovanola                     Lombard Odier Group
# ..                      ...                                     ...
# 83           Sameh elgohary                                  jotmea
# 84              samir kotti                   classe export tunisie
# 85         Samson Parashina    Maasai Wilderness Conservation Trust
# 86          Samson Wainaina                                  Kayuyu
# 87           Samuel Barongo                                     NaN
#
#                        jobTitle               company2              jobTitle2  \
# 0   Senior Curriculum Developer  Mzansi Poetry Academy            Facilitator
# 1      Non Commissioned Officer                    NaN                    NaN
# 2            Investor & Advisor           KOOBA Africa                Founder
# 3            Investor & Advisor           KOOBA Africa                Founder
# 4         Senior Private Banker                   HSBC  Senior Private Banker
# ..                          ...                    ...                    ...
# 83                Sales Manager                    NaN                    NaN
# 84            Chef d'entreprise                    NaN                    NaN
# 85              Conservationist                    NaN                    NaN
# 86                     Director                    NaN                    NaN
# 87            Managing Director                    NaN                    NaN
#
#                     location  Unnamed: 6  \
# 0                Khayelitsha         NaN
# 1                        NaN         NaN
# 2                    Nairobi         NaN
# 3                    Nairobi         NaN
# 4   Région de Genève, Suisse         NaN
# ..                       ...         ...
# 83                       NaN         NaN
# 84            Tuns - Tunisie         NaN
# 85                       NaN         NaN
# 86                       NaN         NaN
# 87                       NaN         NaN
#
#                                              Linkedin
# 0   https://www.linkedin.com/in/reshoketswe-mapokg...
# 1   https://www.linkedin.com/in/cornelius-kitevu-0...
# 2   https://www.linkedin.com/in/richard-bell-4b816...
# 3   https://www.linkedin.com/in/richard-bell-4b816...
# 4   https://www.linkedin.com/in/miguel-ferrer-giov...
# ..                                                ...
# 83  https://www.linkedin.com/in/sameh-elgohary-49b...
# 84  https://www.linkedin.com/in/samir-kotti-643217...
# 85  https://www.linkedin.com/in/samson-parashina-8...
# 86  https://www.linkedin.com/in/samson-wainaina-b0...
# 87  https://www.linkedin.com/in/samuel-barongo-a53...
#
# [88 rows x 8 columns]

# %%
profiles1.drop_duplicates(keep=False, inplace=True)
profiles1.shape
# Out:
# (74, 8)

# %%
full_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f729849b50c6> in <module>
# ----> 1 full_df.shape
#
# NameError: name 'full_df' is not defined

# %%
corr_link = pd.read_csv('./corr_links.csv')
print(corr_link.shape)
corr_link.head()
# Out:
# (196, 13)
#     S/N Person          Full Name First Name    Last Name  \
# 0  4197    Sam            Pauline    Pauline          NaN
# 1  4199    Sam            Pauline    Pauline          NaN
# 2  4201    Sam    Pauline Wachira    Pauline      Wachira
# 3  4203    Sam       Paulo Thomas      Paulo       Thomas
# 4  4210    Sam  Peder Sondergaard      Peder  Sondergaard
#
#                         Email Address Job Title                Organisation  \
# 0                  pauline@m-kopa.com       NaN                         NaN
# 1                pauline@etrade.co.ke       NaN                         NaN
# 2                 pmuhonja1@gmail.com       NaN                         NaN
# 3     paulo.tomas@millenniumangola.ao       NaN  Banco Millennium Angola SA
# 4  peder.sondergaard@apmterminals.com       NaN                         NaN
#
#   Careerl Level Work Country  City Region  \
# 0           NaN          NaN   NaN    NaN
# 1           NaN          NaN   NaN    NaN
# 2     AL Family        Kenya   NaN    NaN
# 3           NaN          NaN   NaN    NaN
# 4           NaN          NaN   NaN    NaN
#
#                                             Linkedin
# 0  https://www.linkedin.com/in/pauline-vaughan-2a...
# 1   https://ke.linkedin.com/in/pauline-komu-54b90247
# 2  https://ke.linkedin.com/in/pauline-wachira-959...
# 3  https://www.linkedin.com/in/paulo-tom%C3%A1s-8...
# 4        https://nl.linkedin.com/in/pedersondergaard

# %%
corr_links.sort_values(by='Full Name', inplace=True)
corr_links.head()
# Out:
# /home/jedi/.pyenv/versions/anaconda3-5.3.0/envs/PyR/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      S/N Person        Full Name First Name Last Name  \
# 4   4197    Sam         Pauline     Pauline       NaN
# 5   4198    Sam         Pauline     Pauline       NaN
# 6   4199    Sam         Pauline     Pauline       NaN
# 8   4201    Sam  Pauline Wachira    Pauline   Wachira
# 10  4203    Sam     Paulo Thomas      Paulo    Thomas
#
#                       Email Address Job Title                Organisation  \
# 4                pauline@m-kopa.com       NaN                         NaN
# 5     pauline.let@contourglobal.com       NaN                         NaN
# 6              pauline@etrade.co.ke       NaN                         NaN
# 8               pmuhonja1@gmail.com       NaN                         NaN
# 10  paulo.tomas@millenniumangola.ao       NaN  Banco Millennium Angola SA
#
#    Careerl Level Work Country  City Region  \
# 4            NaN          NaN   NaN    NaN
# 5            NaN          NaN   NaN    NaN
# 6            NaN          NaN   NaN    NaN
# 8      AL Family        Kenya   NaN    NaN
# 10           NaN          NaN   NaN    NaN
#
#                                              Linkedin
# 4    https://ke.linkedin.com/in/pauline-komu-54b90247
# 5    https://ke.linkedin.com/in/pauline-komu-54b90247
# 6    https://ke.linkedin.com/in/pauline-komu-54b90247
# 8   https://ke.linkedin.com/in/pauline-wachira-959...
# 10  https://www.linkedin.com/in/paulo-tom%C3%A1s-8...

# %%
profiles1.sort_values(by='fullName', inplace=True)

# %%
test = corr_links.copy()

# %%
test.head(100)
# Out:
#       S/N Person                        Full Name             First Name  \
# 4    4197    Sam                         Pauline                 Pauline
# 5    4198    Sam                         Pauline                 Pauline
# 6    4199    Sam                         Pauline                 Pauline
# 8    4201    Sam                  Pauline Wachira                Pauline
# 10   4203    Sam                     Paulo Thomas                  Paulo
# ..    ...    ...                              ...                    ...
# 279  4472    Sam                 Remigius Tenzagh               Remigius
# 281  4474    Sam                   Remo Steinmetz                   Remo
# 286  4479    Sam                 Renuka Jacquette                 Renuka
# 287  4480    Sam  Reshoketswe Blantinah Mapokgole  Reshoketswe Blantinah
# 293  4486    Sam                    Rhoda Kasimbu                  Rhoda
#
#      Last Name                    Email Address  \
# 4          NaN               pauline@m-kopa.com
# 5          NaN    pauline.let@contourglobal.com
# 6          NaN             pauline@etrade.co.ke
# 8      Wachira              pmuhonja1@gmail.com
# 10      Thomas  paulo.tomas@millenniumangola.ao
# ..         ...                              ...
# 279    Tenzagh        remigiustenzagh@yahoo.com
# 281  Steinmetz       remo_steinmetz@swissre.com
# 286  Jacquette    renuka.jacquette@barclays.com
# 287  Mapokgole             rmapokgole@gmail.com
# 293    Kasimbu           rhodakasimbu@gmail.com
#
#                              Job Title                Organisation  \
# 4                                  NaN                         NaN
# 5                                  NaN                         NaN
# 6                                  NaN                         NaN
# 8                                  NaN                         NaN
# 10                                 NaN  Banco Millennium Angola SA
# ..                                 ...                         ...
# 279                                NaN                         NaN
# 281                                NaN                         NaN
# 286  Marketing and Corporate Relations                         NaN
# 287                                NaN                         NaN
# 293                                NaN                         NaN
#
#     Careerl Level Work Country  City Region  \
# 4             NaN          NaN   NaN    NaN
# 5             NaN          NaN   NaN    NaN
# 6             NaN          NaN   NaN    NaN
# 8       AL Family        Kenya   NaN    NaN
# 10            NaN          NaN   NaN    NaN
# ..            ...          ...   ...    ...
# 279           NaN          NaN   NaN    NaN
# 281           NaN          NaN   NaN    NaN
# 286           NaN    Mauritius   NaN    NaN
# 287           NaN          NaN   NaN    NaN
# 293     AL Family          NaN   NaN    NaN
#
#                                               Linkedin
# 4     https://ke.linkedin.com/in/pauline-komu-54b90247
# 5     https://ke.linkedin.com/in/pauline-komu-54b90247
# 6     https://ke.linkedin.com/in/pauline-komu-54b90247
# 8    https://ke.linkedin.com/in/pauline-wachira-959...
# 10   https://www.linkedin.com/in/paulo-tom%C3%A1s-8...
# ..                                                 ...
# 279  https://gh.linkedin.com/in/remigius-tenzagh-40...
# 281           https://ch.linkedin.com/in/remosteinmetz
# 286  https://mu.linkedin.com/in/renuka-jacquette-57...
# 287  https://za.linkedin.com/in/reshoketswe-mapokgo...
# 293  https://ke.linkedin.com/in/cornelius-kitevu-09...
#
# [100 rows x 13 columns]

# %%
linked_2 = pd.read_csv('./filtered_linked_2.csv')
linked_3 = pd.read_csv('./filtered_linked_3.csv')

# %%
linked_2.head()
# Out:
#           fullName                          company  \
# 0     Pauline Komu               ETRADE COMPANY LTD
# 1     Pauline Komu               ETRADE COMPANY LTD
# 2     Pauline Komu               ETRADE COMPANY LTD
# 3  Pauline Wachira  Premier Solar Solutions Limited
# 4      Paulo Tomás       Banco Millennium Atlântico
#
#                                   jobTitle location  \
# 0                                 DIRECTOR      NaN
# 1                                 DIRECTOR      NaN
# 2                                 DIRECTOR      NaN
# 3                           Solar Engineer  Nairobi
# 4  Executive Board Member (vice president)   Luanda
#
#                                      linkedinProfile
# 0  https://www.linkedin.com/in/pauline-komu-54b90...
# 1  https://www.linkedin.com/in/pauline-komu-54b90...
# 2  https://www.linkedin.com/in/pauline-komu-54b90...
# 3  https://www.linkedin.com/in/pauline-wachira-95...
# 4  https://www.linkedin.com/in/paulo-tom%C3%A1s-8...

# %%
linked_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 5 columns):
# fullName           98 non-null object
# company            95 non-null object
# jobTitle           97 non-null object
# location           53 non-null object
# linkedinProfile    98 non-null object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
linked_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
# fullName           14 non-null object
# company            14 non-null object
# jobTitle           14 non-null object
# location           9 non-null object
# linkedinProfile    14 non-null object
# dtypes: object(5)
# memory usage: 688.0+ bytes

# %%
profiles1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 9 to 38
# Data columns (total 8 columns):
# fullName      74 non-null object
# company       72 non-null object
# jobTitle      73 non-null object
# company2      56 non-null object
# jobTitle2     56 non-null object
# location      40 non-null object
# Unnamed: 6    0 non-null float64
# Linkedin      74 non-null object
# dtypes: float64(1), object(7)
# memory usage: 5.2+ KB

# %%
prof = profiles1[['fullName','company','jobTitle','location','Linkedin']]
prof.rename(columns={'Linkedin': 'linkedinProfile'}, inplace=True)
prof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 9 to 38
# Data columns (total 5 columns):
# fullName           74 non-null object
# company            72 non-null object
# jobTitle           73 non-null object
# location           40 non-null object
# linkedinProfile    74 non-null object
# dtypes: object(5)
# memory usage: 3.5+ KB
# /home/jedi/.pyenv/versions/anaconda3-5.3.0/envs/PyR/lib/python3.7/site-packages/pandas/core/frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
linked_3.head()
# Out:
#                   fullName                 company  \
# 0        Samuel Moses Elba        Watson Institute
# 1  Kwame Nkrumah, MBA, CPA      Sleeves Consulting
# 2            Samuel Nwanze          Heirs Holdings
# 3              Samuel Ogbu  Old Mutual West Africa
# 4          Samuel Ogundare   City Of Central Falls
#
#                                             jobTitle  \
# 0                                            Scholar
# 1                                   Managing Partner
# 2  Chief Investment Officer / Director Finance & ...
# 3                      Group Chief Executive Officer
# 4  Business Outreach and Public Relations Coordin...
#
#                       location  \
# 0              America Boulder
# 1                          NaN
# 2               Lagos, Nigeria
# 3                        Lagos
# 4  Central Falls, Rhode Island
#
#                                      linkedinProfile
# 0  https://www.linkedin.com/in/samuel-moses-elba-...
# 1  https://www.linkedin.com/in/kwame-nkrumah-mba-...
# 2  https://www.linkedin.com/in/samuel-nwanze-3b5a...
# 3  https://www.linkedin.com/in/samuel-ogbu-76b44818/
# 4  https://www.linkedin.com/in/samuel-ogundare-43...

# %%
profiles1.head()
# Out:
#                       fullName                  company  \
# 9           CPA Richard Omollo                  FHI 360
# 57           Chipo Masoso Hove                     Buck
# 1             Cornelius Kitevu     Civil Services, Inc.
# 31  DR JANICE RODGERS SAKWANDA    GRID TRANSMISSION LTD
# 79                    Eric Lin  WECAN Technology Co.Ltd
#
#                           jobTitle                                   company2  \
# 9   Global Senior Internal Auditor                CARE International in Kenya
# 57              Investment Analyst                                J.P. Morgan
# 1         Non Commissioned Officer                                        NaN
# 31         C.E.O/MANAGING DIRECTOR                                        NaN
# 79                    Lead Partner  CHINA GREATWALL COMPUTER SHENZHEN CO.,LTD
#
#                               jobTitle2  \
# 9   Senior Audit and Compliance Officer
# 57    Investments Middle Office Analyst
# 1                                   NaN
# 31                                  NaN
# 79                   Technical Director
#
#                                  location  Unnamed: 6  \
# 9   Nairobi with frequent travel globally         NaN
# 57              Edinburgh, United Kingdom         NaN
# 1                                     NaN         NaN
# 31                                    NaN         NaN
# 79             Shenzhen, Guangdong, China         NaN
#
#                                              Linkedin
# 9   https://www.linkedin.com/in/cpa-richard-omollo...
# 57  https://www.linkedin.com/in/chipo-masoso-hove-...
# 1   https://www.linkedin.com/in/cornelius-kitevu-0...
# 31  https://www.linkedin.com/in/dr-janice-rodgers-...
# 79  https://www.linkedin.com/in/eric-lin-922007b/?...

# %%
linked = pd.concat([prof, linked_2, linked_3])
print(linked.shape)
linked.head()
# Out:
# (186, 5)
#                       fullName                  company  \
# 9           CPA Richard Omollo                  FHI 360
# 57           Chipo Masoso Hove                     Buck
# 1             Cornelius Kitevu     Civil Services, Inc.
# 31  DR JANICE RODGERS SAKWANDA    GRID TRANSMISSION LTD
# 79                    Eric Lin  WECAN Technology Co.Ltd
#
#                           jobTitle                               location  \
# 9   Global Senior Internal Auditor  Nairobi with frequent travel globally
# 57              Investment Analyst              Edinburgh, United Kingdom
# 1         Non Commissioned Officer                                    NaN
# 31         C.E.O/MANAGING DIRECTOR                                    NaN
# 79                    Lead Partner             Shenzhen, Guangdong, China
#
#                                       linkedinProfile
# 9   https://www.linkedin.com/in/cpa-richard-omollo...
# 57  https://www.linkedin.com/in/chipo-masoso-hove-...
# 1   https://www.linkedin.com/in/cornelius-kitevu-0...
# 31  https://www.linkedin.com/in/dr-janice-rodgers-...
# 79  https://www.linkedin.com/in/eric-lin-922007b/?...

# %%
linked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 9 to 13
# Data columns (total 5 columns):
# fullName           186 non-null object
# company            181 non-null object
# jobTitle           184 non-null object
# location           102 non-null object
# linkedinProfile    186 non-null object
# dtypes: object(5)
# memory usage: 8.7+ KB

# %%
linked.rename(columns={'fullName':'Full Name','linkedinProfile': 'Linkedin'}, inplace=True)

# %%
linked[linked['Full Name'].str.contains('Pauline')]
# Out:
#          Full Name                          company        jobTitle location  \
# 0     Pauline Komu               ETRADE COMPANY LTD        DIRECTOR      NaN
# 1     Pauline Komu               ETRADE COMPANY LTD        DIRECTOR      NaN
# 2     Pauline Komu               ETRADE COMPANY LTD        DIRECTOR      NaN
# 3  Pauline Wachira  Premier Solar Solutions Limited  Solar Engineer  Nairobi
#
#                                             Linkedin
# 0  https://www.linkedin.com/in/pauline-komu-54b90...
# 1  https://www.linkedin.com/in/pauline-komu-54b90...
# 2  https://www.linkedin.com/in/pauline-komu-54b90...
# 3  https://www.linkedin.com/in/pauline-wachira-95...

# %%
linked[linked.duplicated()]
# Out:
#              Full Name                                            company  \
# 1         Pauline Komu                                 ETRADE COMPANY LTD
# 2         Pauline Komu                                 ETRADE COMPANY LTD
# 42   Prince Awuley,PMP                                      ZEN Petroleum
# 51      Rabin Durbarry  MauBank Ltd (former institutions worked for SB...
# 66         Ralph Gmail                                                NaN
# 69   Raman Subramanian                                  Nakumatt Holdings
# 76  Rania Salah Seddik                                             GebRaa
# 83           Ravi Soni                                    Ravenzo Trading
#
#                                      jobTitle location  \
# 1                                    DIRECTOR      NaN
# 2                                    DIRECTOR      NaN
# 42                             Head Of Retail    Accra
# 51  Head Customer Due Diligence - MauBank Ltd    Ebene
# 66                                responsable      NaN
# 69                                   Director      NaN
# 76                Owner and Managing director      NaN
# 83                                   Director      NaN
#
#                                              Linkedin
# 1   https://www.linkedin.com/in/pauline-komu-54b90...
# 2   https://www.linkedin.com/in/pauline-komu-54b90...
# 42  https://www.linkedin.com/in/prince-awuley-pmp-...
# 51  https://www.linkedin.com/in/rabin-durbarry-a2b...
# 66  https://www.linkedin.com/in/ralph-gmail-30a29771/
# 69  https://www.linkedin.com/in/raman-subramanian-...
# 76  https://www.linkedin.com/in/rania-salah-seddik...
# 83    https://www.linkedin.com/in/ravi-soni-a450868/#

# %%
linked.sort_values(by='Linkedin', inplace=True)
linked.head()
# Out:
#             Full Name                                 company  \
# 77     Aditi Kimatrai  Argus Trading Co Ltd ( Jahazi Designs)
# 59      Andres Bauman                          Elisa Eesti AS
# 48      Jubril Adigun                                Ericsson
# 57  Chipo Masoso Hove                                    Buck
# 1    Cornelius Kitevu                    Civil Services, Inc.
#
#                                  jobTitle                   location  \
# 77                               Director                        NaN
# 59  Senior IT analyst and project manager                        NaN
# 48                          Test Engineer                    Estland
# 57                     Investment Analyst  Edinburgh, United Kingdom
# 1                Non Commissioned Officer                        NaN
#
#                                              Linkedin
# 77  https://www.linkedin.com/in/aditi-kimatrai-003...
# 59  https://www.linkedin.com/in/andres-bauman-67b4...
# 48  https://www.linkedin.com/in/ask4jubad/?locale=...
# 57  https://www.linkedin.com/in/chipo-masoso-hove-...
# 1   https://www.linkedin.com/in/cornelius-kitevu-0...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 71 to 495
# Data columns (total 13 columns):
# S/N              200 non-null int64
# Person           200 non-null object
# Full Name        200 non-null object
# First Name       200 non-null object
# Last Name        163 non-null object
# Email Address    200 non-null object
# Job Title        15 non-null object
# Organisation     7 non-null object
# Careerl Level    25 non-null object
# Work Country     26 non-null object
# City             0 non-null float64
# Region           3 non-null object
# Linkedin         200 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 21.9+ KB

# %%
test.sort_values(by='Linkedin', inplace=True)
test.head()
# Out:
#       S/N Person         Full Name First Name  Last Name  \
# 71   4264    Sam    Peter Wonacott      Peter   Wonacott
# 336  4529    Sam       Rob Vickers        Rob    Vickers
# 521  4714    Sam  Sameer Abubacker     Sameer  Abubacker
# 309  4502    Sam     Richard Lough    Richard      Lough
# 481  4674    Sam           Saiful      Saiful        NaN
#
#                         Email Address Job Title Organisation Careerl Level  \
# 71             peter.wonacott@wsj.com       NaN          NaN           NaN
# 336           rob.vickers@legatum.com       NaN          NaN           NaN
# 521   sameer.abubacker@cnbcarabia.com       NaN          NaN           NaN
# 309  richard.lough@thomsonreuters.com       NaN          NaN           NaN
# 481                 saiful.i@brac.net       NaN          NaN           NaN
#
#     Work Country  City Region  \
# 71           NaN   NaN    NaN
# 336          NaN   NaN    NaN
# 521          NaN   NaN    NaN
# 309          NaN   NaN    NaN
# 481          NaN   NaN    NaN
#
#                                               Linkedin
# 71   https://ae.linkedin.com/in/peter-wonacott-3992...
# 336    https://ae.linkedin.com/in/rob-vickers-0ab7274b
# 521  https://ae.linkedin.com/in/sameer-abubacker-39...
# 309                  https://ar.linkedin.com/in/rlough
# 481  https://bd.linkedin.com/in/saiful-alam-shihab-...

# %%
test[test['Linkedin'].str.contains('https://www.linkedin.com/in/aditi-kimatrai')]
# Out:
# Empty DataFrame
# Columns: [S/N, Person, Full Name, First Name, Last Name, Email Address, Job Title, Organisation, Careerl Level, Work Country, City, Region, Linkedin]
# Index: []

# %%
linked['Linkedin'].head().tolist()
# Out:
# ['https://www.linkedin.com/in/aditi-kimatrai-00397315/',
#  'https://www.linkedin.com/in/andres-bauman-67b4b626/',
#  'https://www.linkedin.com/in/ask4jubad/?locale=de_DE#',
#  'https://www.linkedin.com/in/chipo-masoso-hove-43249231/#',
#  'https://www.linkedin.com/in/cornelius-kitevu-09800b157/']

# %%
# test.loc[test['Full Name'].isin(linked['Full Name']), ['Job Title', 'Organisation', 'Work Country']] = linked[['jobTitle', 'company', 'location']].values
# test.info()
# test[['Job Title', 'Organisation', 'Work Country']] = test['Full Name'].map(linked.set_index('Full Name')[['jobTitle', 'company', 'location']])
# # test.info()

# %%
result = test.merge(linked, on='Full Name').copy()

# %%
result.shape
# Out:
# (88, 17)

# %%
result
# Out:
#      S/N Person           Full Name First Name    Last Name  \
# 0   4264    Sam      Peter Wonacott      Peter     Wonacott
# 1   4529    Sam         Rob Vickers        Rob      Vickers
# 2   4714    Sam    Sameer Abubacker     Sameer    Abubacker
# 3   4502    Sam       Richard Lough    Richard        Lough
# 4   4616    Sam         Ross Osborn       Ross       Osborn
# ..   ...    ...                 ...        ...          ...
# 83  4587    Sam  Ronelle Hutchinson    Ronelle   Hutchinson
# 84  4652    Sam    Saadiq Hendricks     Saadiq    Hendricks
# 85  4690    Sam      Sally Stromnes      Sally     Stromnes
# 86  4753    Sam     Sandile Shongwe    Sandile      Shongwe
# 87  4586    Sam  Ronald Mutandagayi     Ronald  Mutandagayi
#
#                         Email Address Job Title Organisation Careerl Level  \
# 0              peter.wonacott@wsj.com       NaN          NaN           NaN
# 1             rob.vickers@legatum.com       NaN          NaN           NaN
# 2     sameer.abubacker@cnbcarabia.com       NaN          NaN           NaN
# 3    richard.lough@thomsonreuters.com       NaN          NaN           NaN
# 4                  rosborn@pictet.com       NaN          NaN           NaN
# ..                                ...       ...          ...           ...
# 83  ronelle.hutchinson@investec.co.za       NaN          NaN           NaN
# 84         saadiqa.hendricks@bain.com       NaN          NaN           NaN
# 85              sallys@safintra.co.za       NaN          NaN           NaN
# 86               sandilemtn@gmail.com       NaN          NaN           NaN
# 87              rmutandagayi@zb.co.zw       NaN          NaN           NaN
#
#    Work Country  City Region  \
# 0           NaN   NaN    NaN
# 1           NaN   NaN    NaN
# 2           NaN   NaN    NaN
# 3           NaN   NaN    NaN
# 4           NaN   NaN    NaN
# ..          ...   ...    ...
# 83          NaN   NaN    NaN
# 84          NaN   NaN    NaN
# 85          NaN   NaN    NaN
# 86          NaN   NaN    NaN
# 87          NaN   NaN    NaN
#
#                                            Linkedin_x  \
# 0   https://ae.linkedin.com/in/peter-wonacott-3992...
# 1     https://ae.linkedin.com/in/rob-vickers-0ab7274b
# 2   https://ae.linkedin.com/in/sameer-abubacker-39...
# 3                   https://ar.linkedin.com/in/rlough
# 4     https://ch.linkedin.com/in/ross-osborn-810b6611
# ..                                                ...
# 83  https://za.linkedin.com/in/ronelle-hutchinson-...
# 84  https://za.linkedin.com/in/saadiq-hendricks-33...
# 85  https://za.linkedin.com/in/sally-stromnes-5a23...
# 86  https://za.linkedin.com/in/sandile-shongwe-091...
# 87  https://zw.linkedin.com/in/ronald-mutandagayi-...
#
#                                    company  \
# 0                  The Wall Street Journal
# 1                                  Legatum
# 2                              CNBC Arabia
# 3                                  Reuters
# 4                 Pictet Wealth Management
# ..                                     ...
# 83            Investec Wealth & Investment
# 84  TsT Digital Marketing / EdTech Company
# 85                             Safal Group
# 86                                     BBD
# 87           ZB Financial Holdings Limited
#
#                                      jobTitle  \
# 0                        Bureau Chief, Africa
# 1                             General Counsel
# 2   Assistant Manager - Events & Distribution
# 3                 Deputy Bureau Chief, France
# 4                           Directeur Adjoint
# ..                                        ...
# 83                          Portfolio Manager
# 84                              Self Employed
# 85        Marketing Planning and Coordination
# 86               Software Engineer (Graduate)
# 87                      Group Chief Executive
#
#                            location  \
# 0                               NaN
# 1                        Dubai, UAE
# 2                               NaN
# 3                Paris Area, France
# 4                            Geneva
# ..                              ...
# 83                              NaN
# 84                              NaN
# 85  Johannesburg Area, South Africa
# 86  Johannesburg Area, South Africa
# 87                              NaN
#
#                                            Linkedin_y
# 0   https://www.linkedin.com/in/peter-wonacott-399...
# 1   https://www.linkedin.com/in/rob-vickers-0ab727...
# 2   https://www.linkedin.com/in/sameer-abubacker-3...
# 3                 https://www.linkedin.com/in/rlough/
# 4   https://www.linkedin.com/in/ross-osborn-810b66...
# ..                                                ...
# 83  https://www.linkedin.com/in/ronelle-hutchinson...
# 84  https://www.linkedin.com/in/saadiq-hendricks-3...
# 85  https://www.linkedin.com/in/sally-stromnes-5a2...
# 86  https://www.linkedin.com/in/sandile-shongwe-09...
# 87  https://www.linkedin.com/in/ronald-mutandagayi...
#
# [88 rows x 17 columns]

# %%
result[['Job Title', 'Organisation', 'Work Country']] = result[['jobTitle', 'company', 'location']]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 0 to 87
# Data columns (total 17 columns):
# S/N              88 non-null int64
# Person           88 non-null object
# Full Name        88 non-null object
# First Name       88 non-null object
# Last Name        88 non-null object
# Email Address    88 non-null object
# Job Title        88 non-null object
# Organisation     88 non-null object
# Careerl Level    9 non-null object
# Work Country     54 non-null object
# City             0 non-null float64
# Region           3 non-null object
# Linkedin_x       88 non-null object
# company          88 non-null object
# jobTitle         88 non-null object
# location         54 non-null object
# Linkedin_y       88 non-null object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 12.4+ KB

# %%
result.sort_values(by='Full Name', inplace=True)
result.head()
# Out:
#      S/N Person          Full Name First Name    Last Name  \
# 15  4201    Sam    Pauline Wachira    Pauline      Wachira
# 37  4210    Sam  Peder Sondergaard      Peder  Sondergaard
# 56  4214    Sam         Peer Stein       Peer        Stein
# 57  4215    Sam         Peggy Diby      Peggy         Diby
# 45  4227    Sam       Peter Barron      Peter       Barron
#
#                          Email Address  \
# 15                 pmuhonja1@gmail.com
# 37  peder.sondergaard@apmterminals.com
# 56                      pstein@ifc.org
# 57                  peggydiby@yahoo.fr
# 45              peterbarron@google.com
#
#                                             Job Title  \
# 15                                     Solar Engineer
# 37                                          Principal
# 56  Senior Adviser and Global Head of Climate Finance
# 57             Senior Corporate Spokesperson - Global
# 45  VP Communications and Public Affairs, Google EMEA
#
#                                Organisation Careerl Level  \
# 15          Premier Solar Solutions Limited     AL Family
# 37                             Ancored B.V.           NaN
# 56  IFC - International Finance Corporation           NaN
# 57                                   Nestlé           NaN
# 45                                   Google           NaN
#
#                    Work Country  City Region  \
# 15                      Nairobi   NaN    NaN
# 37  The Hague Area, Netherlands   NaN    NaN
# 56   Washington D.C. Metro Area   NaN    NaN
# 57           Vevey, Switzerland   NaN    NaN
# 45       London, United Kingdom   NaN    NaN
#
#                                            Linkedin_x  \
# 15  https://ke.linkedin.com/in/pauline-wachira-959...
# 37        https://nl.linkedin.com/in/pedersondergaard
# 56      https://www.linkedin.com/in/peer-stein-7b4506
# 57   https://www.linkedin.com/in/peggy-diby-5524571a/
# 45    https://uk.linkedin.com/in/peter-barron-376b16a
#
#                                     company  \
# 15          Premier Solar Solutions Limited
# 37                             Ancored B.V.
# 56  IFC - International Finance Corporation
# 57                                   Nestlé
# 45                                   Google
#
#                                              jobTitle  \
# 15                                     Solar Engineer
# 37                                          Principal
# 56  Senior Adviser and Global Head of Climate Finance
# 57             Senior Corporate Spokesperson - Global
# 45  VP Communications and Public Affairs, Google EMEA
#
#                        location  \
# 15                      Nairobi
# 37  The Hague Area, Netherlands
# 56   Washington D.C. Metro Area
# 57           Vevey, Switzerland
# 45       London, United Kingdom
#
#                                            Linkedin_y
# 15  https://www.linkedin.com/in/pauline-wachira-95...
# 37     https://www.linkedin.com/in/pedersondergaard/#
# 56    https://www.linkedin.com/in/peer-stein-7b4506/#
# 57  https://www.linkedin.com/in/peggy-diby-5524571a/#
# 45  https://www.linkedin.com/in/peter-barron-376b1...

# %%
result['Work Country'].value_counts()
# Out:
# Johannesburg Area, South Africa          7
# Paris Area, France                       3
# London, United Kingdom                   3
# Lagos, Nigeria                           2
# Cairo Governorate, Egypt                 2
# Nairobi                                  2
# Cape Town Area, South Africa             1
# Lagos                                    1
# Vienna                                   1
# Kampala                                  1
# Dar es Salaam, Tanzania                  1
# Washington D.C. Metro Area               1
# Austin, Texas Area                       1
# Selfridges London                        1
# The Hague Area, Netherlands              1
# Madagascar / Mauritius                   1
# Mumbai, Maharashtra, India               1
# Ebene, Mauritius                         1
# America Boulder                          1
# Nairobi, Kenya                           1
# Lusaka, Zambia                           1
# Central Falls, Rhode Island              1
# Vevey, Switzerland                       1
# Iles   Ocean Indien                      1
# East Africa                              1
# Greater New York City Area               1
# Casablanca, Grand Casablanca, Morocco    1
# San Francisco                            1
# Mauritius                                1
# Zambia                                   1
# Based in the Netherlands, Amsterdam      1
# Accra, Ghana                             1
# Arkansas                                 1
# Geneva                                   1
# Tanzania                                 1
# Paris und Umgebung, Frankreich           1
# Hannover, Germany                        1
# London                                   1
# Uganda                                   1
# Dubai, UAE                               1
# Greater Atlanta Area                     1
# Name: Work Country, dtype: int64

# %%
# result['Work Country'][0].split()[-1]

# %%
filt = result[ 'location'].str.contains(",")==True
result['Work Country'] = result['Work Country'].where(~filt , result['location'].str.partition(",")[2])

# %%
result
# Out:
#      S/N Person          Full Name First Name    Last Name  \
# 15  4201    Sam    Pauline Wachira    Pauline      Wachira
# 37  4210    Sam  Peder Sondergaard      Peder  Sondergaard
# 56  4214    Sam         Peer Stein       Peer        Stein
# 57  4215    Sam         Peggy Diby      Peggy         Diby
# 45  4227    Sam       Peter Barron      Peter       Barron
# ..   ...    ...                ...        ...          ...
# 75  4740    Sam    Samuel Ogundare     Samuel     Ogundare
# 26  4747    Sam       Sanae Lahlou      Sanae       Lahlou
# 54  4749    Sam        Sandie King     Sandie         King
# 86  4753    Sam    Sandile Shongwe    Sandile      Shongwe
# 55  4760    Sam  Sandrine Ingabire   Sandrine     Ingabire
#
#                          Email Address  \
# 15                 pmuhonja1@gmail.com
# 37  peder.sondergaard@apmterminals.com
# 56                      pstein@ifc.org
# 57                  peggydiby@yahoo.fr
# 45              peterbarron@google.com
# ..                                 ...
# 75          samuelogundare64@yahoo.com
# 26              sanae.lahlou@mazars.ma
# 54               sandie.king@gcu.ac.uk
# 86                sandilemtn@gmail.com
# 55          sandry.ingabire7@gmail.com
#
#                                             Job Title  \
# 15                                     Solar Engineer
# 37                                          Principal
# 56  Senior Adviser and Global Head of Climate Finance
# 57             Senior Corporate Spokesperson - Global
# 45  VP Communications and Public Affairs, Google EMEA
# ..                                                ...
# 75  Business Outreach and Public Relations Coordin...
# 26                               Directeur BU AFRIQUE
# 54                                           Director
# 86                       Software Engineer (Graduate)
# 55                           Divisional Sales Manager
#
#                                Organisation Careerl Level  \
# 15          Premier Solar Solutions Limited     AL Family
# 37                             Ancored B.V.           NaN
# 56  IFC - International Finance Corporation           NaN
# 57                                   Nestlé           NaN
# 45                                   Google           NaN
# ..                                      ...           ...
# 75                    City Of Central Falls     AL Family
# 26                             Mazars Maroc           ALN
# 54                         Landaur Coaching           NaN
# 86                                      BBD           NaN
# 55                              Kurt Geiger     AL Family
#
#                   Work Country  City Region  \
# 15                     Nairobi   NaN    NaN
# 37                 Netherlands   NaN    NaN
# 56  Washington D.C. Metro Area   NaN    NaN
# 57                 Switzerland   NaN    NaN
# 45              United Kingdom   NaN    NaN
# ..                         ...   ...    ...
# 75                Rhode Island   NaN    NaN
# 26                         NaN   NaN    NaN
# 54                         NaN   NaN    NaN
# 86                South Africa   NaN    NaN
# 55           Selfridges London   NaN    NaN
#
#                                            Linkedin_x  \
# 15  https://ke.linkedin.com/in/pauline-wachira-959...
# 37        https://nl.linkedin.com/in/pedersondergaard
# 56      https://www.linkedin.com/in/peer-stein-7b4506
# 57   https://www.linkedin.com/in/peggy-diby-5524571a/
# 45    https://uk.linkedin.com/in/peter-barron-376b16a
# ..                                                ...
# 75  https://www.linkedin.com/in/samuel-ogundare-43...
# 26   https://ma.linkedin.com/in/sanae-lahlou-968b10aa
# 54    https://uk.linkedin.com/in/sandie-king-51776915
# 86  https://za.linkedin.com/in/sandile-shongwe-091...
# 55  https://uk.linkedin.com/in/sandrine-ingabire-7...
#
#                                     company  \
# 15          Premier Solar Solutions Limited
# 37                             Ancored B.V.
# 56  IFC - International Finance Corporation
# 57                                   Nestlé
# 45                                   Google
# ..                                      ...
# 75                    City Of Central Falls
# 26                             Mazars Maroc
# 54                         Landaur Coaching
# 86                                      BBD
# 55                              Kurt Geiger
#
#                                              jobTitle  \
# 15                                     Solar Engineer
# 37                                          Principal
# 56  Senior Adviser and Global Head of Climate Finance
# 57             Senior Corporate Spokesperson - Global
# 45  VP Communications and Public Affairs, Google EMEA
# ..                                                ...
# 75  Business Outreach and Public Relations Coordin...
# 26                               Directeur BU AFRIQUE
# 54                                           Director
# 86                       Software Engineer (Graduate)
# 55                           Divisional Sales Manager
#
#                            location  \
# 15                          Nairobi
# 37      The Hague Area, Netherlands
# 56       Washington D.C. Metro Area
# 57               Vevey, Switzerland
# 45           London, United Kingdom
# ..                              ...
# 75      Central Falls, Rhode Island
# 26                              NaN
# 54                              NaN
# 86  Johannesburg Area, South Africa
# 55                Selfridges London
#
#                                            Linkedin_y
# 15  https://www.linkedin.com/in/pauline-wachira-95...
# 37     https://www.linkedin.com/in/pedersondergaard/#
# 56    https://www.linkedin.com/in/peer-stein-7b4506/#
# 57  https://www.linkedin.com/in/peggy-diby-5524571a/#
# 45  https://www.linkedin.com/in/peter-barron-376b1...
# ..                                                ...
# 75  https://www.linkedin.com/in/samuel-ogundare-43...
# 26  https://www.linkedin.com/in/sanae-lahlou-968b1...
# 54  https://www.linkedin.com/in/sandie-king-517769...
# 86  https://www.linkedin.com/in/sandile-shongwe-09...
# 55  https://www.linkedin.com/in/sandrine-ingabire-...
#
# [88 rows x 17 columns]

# %%
filt = result[ 'location'].str.contains(",")==False
result['City'] = result['Work Country'].where(filt , result['location'].str.partition(",")[0])

# %%
data.rename(columns={'Careerl Level': 'Career Level'}, inplace=True)
result2 = result[data.columns.tolist()]
result2.to_csv('./results.csv')

# %%
result[pd.notnull(result['City'])]
print(result[pd.notnull(result['City'])].shape)
# Out:
# (54, 17)

# %%
result['Job Title'].value_counts()
# Out:
# Partner                               4
# Director                              4
# Chairman & CEO                        2
# CEO                                   2
# Managing Director                     2
#                                      ..
# Director, Business Development        1
# Corporate Affairs Director            1
# Regional Head of Economics, Africa    1
# Business Advisor                      1
# Managing Partner                      1
# Name: Job Title, Length: 79, dtype: int64

# %%
result.shape
# Out:
# (88, 17)

# %%
result.to_csv('./results.csv')

# %%
result.rename(columns={'Careerl Level': 'Career Level'}, inplace=True)

# %%
mid_lev = ['Head', 'Director', 'Manager', 'Senior', 'Deputy chief of staff', 'Principal', 'Member Of Parliament', 'Managing Editor', 'Head of Department', 'Project Manager', 'Senior Consultant']

# %%
CEO = ['CEO','Chief Executive Officer & Co-Founder','Country Director', 'Managing Partner','Managing Director', 'Managing director','MD', 'Managing partner', 'Founder', 'founder', 'Co-founder', 'President' , 'Executive Director', 'Country Manager', 'Chief Executive Officer', 'Chairman', 'Chairperson', 'Executive Producer', 'Owner', 'Chair', 'Managing Partner', 'Country Director']
len(CEO)
# Out:
# 22

# %%
# ceo_filter = ((result['Job Title'] == 'Principal') | (result['Job Title'].str.contains('|'.join(CEO)na=False))) & (result['Job Title'].str.contains('Deputy|Vice')==False)
# ceo_filter = ((result['Job Title'] == 'Principal') | (result['Job Title'].str.contains('|'.join(CEO)) == True)) & (result['Job Title'].str.contains('Deputy|Vice')==False)

ceo_df = result[result['Job Title'].str.contains(r'|'.join(CEO))]
print(ceo_df.shape)
ceo_df['Job Title'].value_counts()
# Out:
# (18, 17)
# Chairman & CEO                                                    2
# CEO                                                               2
# Managing Director                                                 2
# Country Director                                                  1
# Chief Executive Officer & Co-Founder                              1
# Group Chief Executive Officer                                     1
# Country Manager                                                   1
# MD & Ceo                                                          1
# Managing Director, South Africa & Sub-saharan Africa Cluster      1
# Vice President, Head of Mastercard Lab for Financial Inclusion    1
# Chairman and Chief Executive Officer                              1
# Founder & CEO                                                     1
# Co Managing Partner                                               1
# Founder, Chair, and CEO                                           1
# Managing Partner                                                  1
# Name: Job Title, dtype: int64

# %%
results['Career Level'] = pd.np.where(result['Job Title'].str.contains('|'.join(CEO)), 'CEO',
                                      result['Job Title'].str.contains('|'.join(S_Exec)))

# %%
ceo_df.loc[:,'Career Level'] = 'CEO'
ceo_df.head()
# Out:
#      S/N Person      Full Name First Name Last Name  \
# 59  4238    Sam  Peter Kellner      Peter   Kellner
# 39  4251    Sam     Peter Mlay      Peter      Mlay
# 33  4259    Sam   Peter Owoeye      Peter    Owoeye
# 61  4269    Sam    Peyami Oven     Peyami      Oven
# 77  4309    Sam   Pierre Malan     Pierre     Malan
#
#                                   Email Address                Job Title  \
# 59                peter.kellner@richmondmgt.com  Founder, Chair, and CEO
# 39                     peter.mlay@cellulant.com          Country Manager
# 33                       peter.owoeye@gmail.com                      CEO
# 61  mariechristine.boncilhon@totalmauritius.com        Managing Director
# 77                 pierre.malan@acornequity.com                      CEO
#
#                    Organisation Career Level                Work Country  \
# 59      Richmond Global Compass          CEO  Greater New York City Area
# 39   Cellulant Tanzania Limited          CEO                    Tanzania
# 33  Bay Royal International Ltd          CEO                         NaN
# 61                  Total Egypt          CEO                       Egypt
# 77         Acorn Private Equity          CEO                         NaN
#
#                           City Region  \
# 59  Greater New York City Area    NaN
# 39                    Tanzania    NaN
# 33                         NaN    NaN
# 61           Cairo Governorate    NaN
# 77                         NaN    NaN
#
#                                            Linkedin_x  \
# 59    https://www.linkedin.com/in/peter-kellner-05677
# 39     https://tz.linkedin.com/in/peter-mlay-64b6a684
# 33    https://ng.linkedin.com/in/peter-owoeye-817aa68
# 61  https://www.linkedin.com/in/peyami-oven-bb45b7160
# 77   https://za.linkedin.com/in/pierre-malan-a572063a
#
#                         company                 jobTitle  \
# 59      Richmond Global Compass  Founder, Chair, and CEO
# 39   Cellulant Tanzania Limited          Country Manager
# 33  Bay Royal International Ltd                      CEO
# 61                  Total Egypt        Managing Director
# 77         Acorn Private Equity                      CEO
#
#                       location  \
# 59  Greater New York City Area
# 39                    Tanzania
# 33                         NaN
# 61    Cairo Governorate, Egypt
# 77                         NaN
#
#                                            Linkedin_y
# 59   https://www.linkedin.com/in/peter-kellner-05677/
# 39  https://www.linkedin.com/in/peter-mlay-64b6a684/#
# 33  https://www.linkedin.com/in/peter-owoeye-817aa...
# 61  https://www.linkedin.com/in/peyami-oven-bb45b7...
# 77  https://www.linkedin.com/in/pierre-malan-a5720...

# %%
exec_filter =(result['Job Title'].str.contains('|'.join(S_Exec)) == True) | (result['Job Title'].str.contains(r'(?=.*Head)(?=.*Director)') == True)
exec_df = result[exec_filter]
exec_df
# Out:
#      S/N Person           Full Name First Name    Last Name  \
# 56  4214    Sam          Peer Stein       Peer        Stein
# 45  4227    Sam        Peter Barron      Peter       Barron
# 46  4229    Sam         Peter Flade      Peter        Flade
# 38  4236    Sam       Peter Kasanda      Peter      Kasanda
# 12  4287    Sam        Philip Sowah     Philip        Sowah
# 62  4343    Sam   Progress Chisenga   Progress     Chisenga
# 27  4378    Sam       Rahman Bholah     Rahman       Bholah
# 25  4444    Sam      Raymond Farhat    Raymond       Farhat
# 19  4453    Sam    Rebecca Harrison    Rebecca     Harrison
# 40  4465    Sam    Reginald Massawe   Reginald      Massawe
# 64  4498    Sam       Richard Glass    Richard        Glass
# 67  4527    Sam           Rob Eloff        Rob        Eloff
# 87  4586    Sam  Ronald Mutandagayi     Ronald  Mutandagayi
# 44  4615    Sam      Ross Masterman       Ross    Masterman
# 72  4678    Sam          Salah Goss      Salah         Goss
# 36  4739    Sam         Samuel Ogbu     Samuel         Ogbu
#
#                            Email Address  \
# 56                        pstein@ifc.org
# 45                peterbarron@google.com
# 46              peter_flade@gallup.co.uk
# 38             peter.kasanda@clydeco.com
# 12            philip.sowah@gh.airtel.com
# 62             proggy.chisenga@gmail.com
# 27                        bholah@dhl.com
# 25      raymond.farhat@sahamfinances.com
# 19           rebecca@africanmanagers.org
# 40  reginald.m@africanmicrofinance.co.tz
# 64                  richard@jwflegal.com
# 67                      reloff@latcap.co
# 87                 rmutandagayi@zb.co.zw
# 44             rossmasterman@hotmail.com
# 72             salah.goss@mastercard.com
# 36             samuel.ogbu@liberty.co.za
#
#                                             Job Title  \
# 56  Senior Adviser and Global Head of Climate Finance
# 45  VP Communications and Public Affairs, Google EMEA
# 46                                            Partner
# 38                                            Partner
# 12                                            Partner
# 62                                   Country Director
# 27                                    General Manager
# 25                                Co Managing Partner
# 19               Chief Executive Officer & Co-Founder
# 40               Chairman and Chief Executive Officer
# 64                                            Partner
# 67                                   Managing Partner
# 87                              Group Chief Executive
# 44                            Chief Financial Officer
# 72  Vice President, Head of Mastercard Lab for Fin...
# 36                      Group Chief Executive Officer
#
#                                Organisation Career Level  \
# 56  IFC - International Finance Corporation          NaN
# 45                                   Google          NaN
# 46                             ALL IN WORKS          NaN
# 38                           Clyde & Co LLP          NaN
# 12      Nubuke Business Investment Advisory          NaN
# 62                                    Kwesé          NaN
# 27                      DHL (Mauritius) Ltd          NaN
# 25                            EMERGE Invest          NaN
# 19             African Management Institute          NaN
# 40             African Microfinance Limited          NaN
# 64                       John W Ffooks & Co          NaN
# 67                          Lateral Capital          NaN
# 87            ZB Financial Holdings Limited          NaN
# 44                                Umeme Ltd          NaN
# 72                               Mastercard          NaN
# 36                   Old Mutual West Africa          NaN
#
#                   Work Country                        City Region  \
# 56  Washington D.C. Metro Area  Washington D.C. Metro Area    NaN
# 45              United Kingdom                      London    NaN
# 46                         NaN                         NaN    NaN
# 38                    Tanzania               Dar es Salaam    NaN
# 12                         NaN                         NaN    NaN
# 62                      Zambia                      Zambia    NaN
# 27                   Mauritius                   Mauritius    NaN
# 25   Grand Casablanca, Morocco                  Casablanca    NaN
# 19                     Nairobi                     Nairobi    NaN
# 40                         NaN                         NaN    NaN
# 64      Madagascar / Mauritius      Madagascar / Mauritius    NaN
# 67                South Africa              Cape Town Area    NaN
# 87                         NaN                         NaN    NaN
# 44                     Kampala                     Kampala    NaN
# 72                         NaN                         NaN    NaN
# 36                       Lagos                       Lagos    NaN
#
#                                            Linkedin_x  \
# 56      https://www.linkedin.com/in/peer-stein-7b4506
# 45    https://uk.linkedin.com/in/peter-barron-376b16a
# 46           https://uk.linkedin.com/in/peterflade/de
# 38   https://tz.linkedin.com/in/peter-kasanda-606b825
# 12             https://gh.linkedin.com/in/philipsowah
# 62       https://www.linkedin.com/in/progresschisenga
# 27  https://mu.linkedin.com/in/rahman-bholah-81684780
# 25  https://ma.linkedin.com/in/raymond-farhat-8297...
# 19  https://ke.linkedin.com/in/rebecca-harrison-27...
# 40  https://tz.linkedin.com/in/reginald-massawe-ba...
# 64          https://www.linkedin.com/in/richardkglass
# 67     https://www.linkedin.com/in/rob-eloff-54991b72
# 87  https://zw.linkedin.com/in/ronald-mutandagayi-...
# 44  https://ug.linkedin.com/in/ross-masterman-4433...
# 72   https://www.linkedin.com/in/salah-goss-3245a4123
# 36    https://ng.linkedin.com/in/samuel-ogbu-76b44818
#
#                                     company  \
# 56  IFC - International Finance Corporation
# 45                                   Google
# 46                             ALL IN WORKS
# 38                           Clyde & Co LLP
# 12      Nubuke Business Investment Advisory
# 62                                    Kwesé
# 27                      DHL (Mauritius) Ltd
# 25                            EMERGE Invest
# 19             African Management Institute
# 40             African Microfinance Limited
# 64                       John W Ffooks & Co
# 67                          Lateral Capital
# 87            ZB Financial Holdings Limited
# 44                                Umeme Ltd
# 72                               Mastercard
# 36                   Old Mutual West Africa
#
#                                              jobTitle  \
# 56  Senior Adviser and Global Head of Climate Finance
# 45  VP Communications and Public Affairs, Google EMEA
# 46                                            Partner
# 38                                            Partner
# 12                                            Partner
# 62                                   Country Director
# 27                                    General Manager
# 25                                Co Managing Partner
# 19               Chief Executive Officer & Co-Founder
# 40               Chairman and Chief Executive Officer
# 64                                            Partner
# 67                                   Managing Partner
# 87                              Group Chief Executive
# 44                            Chief Financial Officer
# 72  Vice President, Head of Mastercard Lab for Fin...
# 36                      Group Chief Executive Officer
#
#                                  location  \
# 56             Washington D.C. Metro Area
# 45                 London, United Kingdom
# 46                                    NaN
# 38                Dar es Salaam, Tanzania
# 12                                    NaN
# 62                                 Zambia
# 27                              Mauritius
# 25  Casablanca, Grand Casablanca, Morocco
# 19                                Nairobi
# 40                                    NaN
# 64                 Madagascar / Mauritius
# 67           Cape Town Area, South Africa
# 87                                    NaN
# 44                                Kampala
# 72                                    NaN
# 36                                  Lagos
#
#                                            Linkedin_y
# 56    https://www.linkedin.com/in/peer-stein-7b4506/#
# 45  https://www.linkedin.com/in/peter-barron-376b1...
# 46  https://www.linkedin.com/in/peterflade/?locale...
# 38  https://www.linkedin.com/in/peter-kasanda-606b...
# 12          https://www.linkedin.com/in/philipsowah/#
# 62     https://www.linkedin.com/in/progresschisenga/#
# 27  https://www.linkedin.com/in/rahman-bholah-8168...
# 25  https://www.linkedin.com/in/raymond-farhat-829...
# 19  https://www.linkedin.com/in/rebecca-harrison-2...
# 40  https://www.linkedin.com/in/reginald-massawe-b...
# 64        https://www.linkedin.com/in/richardkglass/#
# 67   https://www.linkedin.com/in/rob-eloff-54991b72/#
# 87  https://www.linkedin.com/in/ronald-mutandagayi...
# 44  https://www.linkedin.com/in/ross-masterman-443...
# 72  https://www.linkedin.com/in/salah-goss-3245a41...
# 36  https://www.linkedin.com/in/samuel-ogbu-76b44818/

# %%
mid_filter = (non_execs['Job Title'].str.contains('|'.join(mid_lev)) == True)
