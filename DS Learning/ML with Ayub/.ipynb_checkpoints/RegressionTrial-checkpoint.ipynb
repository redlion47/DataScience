# %% [markdown]
# # Workbench

# %% [markdown]
# **Import packages**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mp
# %matplotlib inline

# %%
supermarket_df = pd.read_csv("supermarket_till_transactions.csv")
supermarket_df.sample(5)
# Out:
#      SHOP_WEEK  SHOP_DATE  SHOP_WEEKDAY  SHOP_HOUR  QUANTITY  SPEND  \
# 118     200607   20060414             6         19         1    499
# 44      200607   20060413             5          8         1     66
# 96      200607   20060412             4         15         1    101
# 59      200607   20060410             2          9         3    294
# 28      200607   20060414             6         15         1    219
#
#       PROD_CODE PROD_CODE_10 PROD_CODE_20 PROD_CODE_30     ...       \
# 118  PRD0903833      CL00234     DEP00083       G00028     ...
# 44   PRD0904867      CL00157     DEP00053       G00016     ...
# 96   PRD0903074      CL00045     DEP00011       G00004     ...
# 59   PRD0903351      CL00005     DEP00002       G00001     ...
# 28   PRD0904370      CL00068     DEP00019       G00007     ...
#
#     CUST_PRICE_SENSITIVITY CUST_LIFESTAGE        BASKET_ID BASKET_SIZE  \
# 118                     LA             OA  994100100540327           M
# ...

# %%
supermarket_df.columns
# Out:
# Index(['SHOP_WEEK', 'SHOP_DATE', 'SHOP_WEEKDAY', 'SHOP_HOUR', 'QUANTITY',
#        'SPEND', 'PROD_CODE', 'PROD_CODE_10', 'PROD_CODE_20', 'PROD_CODE_30',
#        'PROD_CODE_40', 'CUST_CODE', 'CUST_PRICE_SENSITIVITY', 'CUST_LIFESTAGE',
#        'BASKET_ID', 'BASKET_SIZE', 'BASKET_PRICE_SENSITIVITY', 'BASKET_TYPE',
#        'BASKET_DOMINANT_MISSION', 'STORE_CODE', 'STORE_FORMAT',
#        'STORE_REGION'],
#       dtype='object')

# %%
supermarket_df = supermarket_df.drop(columns=['PROD_CODE', 'PROD_CODE_10', 'PROD_CODE_20', 'PROD_CODE_30',
       'PROD_CODE_40'])
supermarket_df.sample(5)
# Out:
#     SHOP_WEEK  SHOP_DATE  SHOP_WEEKDAY  SHOP_HOUR  QUANTITY  SPEND  \
# 85     200607   20060412             4         13         1     67
# 15     200607   20060414             6         15         1     75
# 14     200607   20060414             6         15         1    108
# 46     200607   20060410             2          9         1     52
# 5      200607   20060413             5         20         6    156
#
#          CUST_CODE CUST_PRICE_SENSITIVITY CUST_LIFESTAGE        BASKET_ID  \
# 85             NaN                    NaN            NaN  994100100058515
# 15  CUST0000089820                     LA             OT  994100100206797
# 14  CUST0000089820                     LA             OT  994100100206797
# 46             NaN                    NaN            NaN  994100100014637
# 5   CUST0000634693                     LA             YF  994100100532898
#
#    BASKET_SIZE BASKET_PRICE_SENSITIVITY BASKET_TYPE BASKET_DOMINANT_MISSION  \
# ...
